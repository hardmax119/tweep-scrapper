# %%
import pandas as pd

df = pd.read_csv('../data/tweets.csv')
df.head()
# Out:
#   username                                               text  \
# 0  NatWest  EarthSense, a Leicester-based scaleup speciali...
# 1  NatWest  The end of an era. We're so proud of our @Team...
# 2  NatWest  We're proud of our @TeamGB ambassador, Beth Sh...
# 3  NatWest  Congrats to Duncan Scott on another medal win ...
# 4  NatWest  What a result! Congratulations to Helen Glover...
#
#    thumbnail_title  thumbnail_url  \
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
#
#                                            tweet_url  \
# 0  [{'display_url': 'spkl.io/6013f8uIl', 'expande...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                   created_at  retweets  likes  views
# ...

# %%
for t in df['text'].sample(10):
    print(t)
# Out:
# We've partnered with @TeamGB to inspire you to take action towards your goals today. #LetsGetGoing #TeamGB #Olympics #Paris2024 https://t.co/tspY5SZhv1
# Congrats to Duncan Scott on another medal win and becoming Scotland's most decorated Olympian. What an achievement! @teamgb
#
# #TomorrowBeginsToday #TeamGB #Swimming #Paris2024 #Olympics https://t.co/kCLLPF0pg6
# Don’t miss out on the action! Watch live coverage of the Paris 2024 Olympic Games at the @TeamGB Fanzones in London and Manchester, Open daily 12-11pm from 26 July to 11 August.
#
# London - Battersea Power Station, Power Station Park, SW11 8DD
# Manchester - Spinningfields, M3 3AE https://t.co/h0ykA2xz8e
# Small actions make a big difference, go for gold with NatWest and Chris Hoy #LetsGetGoing #TeamGB #Olympics #Paris2024 https://t.co/CFWwGyJzjx
# Ever wondered what keeps an Olympic swimmer motivated? Duncan Scott answers our quick fire questions #TeamGB #Olympics #Paris2024 https://t.co/lHAjcZyn8w
# ...
